# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_csv("./yellow_tripdata_2015-01.csv/yellow_tripdata_2015-01.csv", nrows=100)

# %%
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	pickup_longitude FLOAT(53),
# 	pickup_latitude FLOAT(53),
# 	"RateCodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	dropoff_longitude FLOAT(53),
# 	dropoff_latitude FLOAT(53),
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53)
# )

# %%
df_iter = pd.read_csv("./yellow_tripdata_2015-01.csv/yellow_tripdata_2015-01.csv", iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
df.head(n=0).to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")
# Out:
# 0

# %%
# %time df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
# Out:
# CPU times: total: 3.31 s
# Wall time: 9.85 s
# 1000

# %%
from time import time

# %%
count = 1
while True:
    t_start = time()
    
    df = next(df_iter)
    print(f"inserting {count} interation")
    
    print("convert time fields to timestamps")
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    
    print("inserting data to sql")
    df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
    
    t_end = time()
    
    print(f"inserted chunk no. {count}...., took {t_end - t_start} time")
    count = count + 1
# Out:
# inserting 1 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 1...., took 10.03295636177063 time
# inserting 2 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 2...., took 9.862435579299927 time
# inserting 3 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 3...., took 12.616307973861694 time
# inserting 4 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 4...., took 13.22031283378601 time
# inserting 5 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 5...., took 12.60539197921753 time
# inserting 6 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 6...., took 11.46901535987854 time
# inserting 7 interation
# convert time fields to timestamps
# inserting data to sql
# inserted chunk no. 7...., took 12.925875186920166 time
# ...
